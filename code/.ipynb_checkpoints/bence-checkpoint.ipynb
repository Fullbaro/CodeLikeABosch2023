# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/DevelopmentData.csv', sep=';')
data.set_index('Unnamed: 0', inplace=True)
data.index.rename('ind', inplace=True)
data.columns
# Out:
# Index(['FirstObjectDistance_X', 'FirstObjectDistance_Y',
#        'SecondObjectDistance_X', 'SecondObjectDistance_Y',
#        'ThirdObjectDistance_X', 'ThirdObjectDistance_Y',
#        'FourthObjectDistance_X', 'FourthObjectDistance_Y', 'VehicleSpeed',
#        'FirstObjectSpeed_X', 'FirstObjectSpeed_Y', 'SecondObjectSpeed_X',
#        'SecondObjectSpeed_Y', 'ThirdObjectSpeed_X', 'ThirdObjectSpeed_Y',
#        'FourthObjectSpeed_X', 'FourthObjectSpeed_Y', 'YawRate', 'Timestamp'],
#       dtype='object')

# %%
data_norm = data.copy()

data_norm[['FirstObjectDistance_X', 'FirstObjectDistance_Y', 'SecondObjectDistance_X', 'SecondObjectDistance_Y', 'ThirdObjectDistance_X', 'ThirdObjectDistance_Y', 'FourthObjectDistance_X', 'FourthObjectDistance_Y']] = \
data[['FirstObjectDistance_X', 'FirstObjectDistance_Y', 'SecondObjectDistance_X', 'SecondObjectDistance_Y', 'ThirdObjectDistance_X', 'ThirdObjectDistance_Y', 'FourthObjectDistance_X', 'FourthObjectDistance_Y']] / 128

data_norm[['VehicleSpeed', 'FirstObjectSpeed_X', 'FirstObjectSpeed_Y', 'SecondObjectSpeed_X', 'SecondObjectSpeed_Y', 'ThirdObjectSpeed_X', 'ThirdObjectSpeed_Y', 'FourthObjectSpeed_X', 'FourthObjectSpeed_Y']] = \
data[['VehicleSpeed', 'FirstObjectSpeed_X', 'FirstObjectSpeed_Y', 'SecondObjectSpeed_X', 'SecondObjectSpeed_Y', 'ThirdObjectSpeed_X', 'ThirdObjectSpeed_Y', 'FourthObjectSpeed_X', 'FourthObjectSpeed_Y']] / 256

data_norm
# Out:
#      FirstObjectDistance_X  FirstObjectDistance_Y  SecondObjectDistance_X  \
# ind
# 0                64.148438              11.281250               42.617188
# 1                64.125000              11.273438               42.617188
# 2                64.148438              11.281250               42.601562
# 3                64.132812              11.289062               42.593750
# 4                64.132812              11.289062               42.593750
# ..                     ...                    ...                     ...
# 423               6.109375              -4.601562               77.437500
# 424               6.445312              -4.835938               77.429688
# 425               6.406250              -4.929688               77.390625
# 426               6.562500              -5.031250               77.359375
# 427               6.476562              -5.078125               77.320312
#
#      SecondObjectDistance_Y  ThirdObjectDistance_X  ThirdObjectDistance_Y  \
# ind
# 0                 -9.007812              24.242188              -9.664062
# 1                 -9.007812              24.234375              -9.664062
# 2                 -9.062500              24.250000              -9.625000
# 3                 -9.109375              24.250000              -9.625000
# 4                 -9.117188              24.265625              -9.570312
# ..                      ...                    ...                    ...
# 423              -16.179688               0.000000               0.000000
# 424              -16.132812               0.000000               0.000000
# 425              -16.093750               0.000000               0.000000
# 426              -15.992188               0.000000               0.000000
# 427              -15.945312               0.000000               0.000000
#
#      FourthObjectDistance_X  FourthObjectDistance_Y  VehicleSpeed  \
# ind
# 0                 93.937500               13.398438           0.0
# 1                  0.000000                0.000000           0.0
# 2                  0.000000                0.000000           0.0
# 3                  0.000000                0.000000           0.0
# 4                  0.000000                0.000000           0.0
# ..                      ...                     ...           ...
# 423                8.945312               -5.726562           0.0
# 424                8.937500               -5.726562           0.0
# 425                8.953125               -5.703125           0.0
# 426                8.945312               -5.703125           0.0
# 427                8.921875               -5.687500           0.0
#
#      FirstObjectSpeed_X  FirstObjectSpeed_Y  SecondObjectSpeed_X  \
# ind
# 0             -0.007812            0.000000             0.015625
# 1             -0.015625            0.000000            -0.007812
# 2             -0.011719            0.000000            -0.003906
# 3             -0.015625            0.000000             0.000000
# 4              0.000000            0.003906             0.000000
# ..                  ...                 ...                  ...
# 423            1.093750           -0.687500             0.039062
# 424            2.718750           -0.597656             0.011719
# 425            2.632812           -0.597656             0.039062
# 426            2.625000           -0.503906             0.042969
# 427            2.265625           -0.304688             0.019531
#
#      SecondObjectSpeed_Y  ThirdObjectSpeed_X  ThirdObjectSpeed_Y  \
# ind
# 0               0.003906            0.003906            0.027344
# 1               0.011719            0.000000            0.023438
# 2              -0.035156            0.019531            0.031250
# 3              -0.054688            0.011719            0.046875
# 4              -0.042969            0.031250            0.062500
# ..                   ...                 ...                 ...
# 423             0.132812            0.000000            0.000000
# 424             0.148438            0.000000            0.000000
# 425             0.121094            0.000000            0.000000
# 426             0.136719            0.000000            0.000000
# 427             0.136719            0.000000            0.000000
#
#      FourthObjectSpeed_X  FourthObjectSpeed_Y   YawRate  Timestamp
# ind
# 0               0.027344             0.000000  0.000000  33.241504
# 1               0.000000             0.000000  0.000000  33.335960
# 2               0.000000             0.000000  0.000000  33.429725
# 3               0.000000             0.000000  0.000000  33.522769
# 4               0.000000             0.000000  0.000000  33.618715
# ..                   ...                  ...       ...        ...
# 423             0.003906            -0.039062 -0.001343  72.804477
# 424             0.027344            -0.019531 -0.001343  72.889443
# 425             0.070312            -0.019531 -0.001343  72.972854
# 426             0.074219            -0.011719 -0.001343  73.057103
# 427             0.125000            -0.027344 -0.001343  73.143584
#
# [428 rows x 19 columns]

# %%
data_norm.to_csv('../data/data_norm.csv', sep=';')

# %%
data_norm[['FirstObjectDistance_X', 'FirstObjectDistance_Y']]
plt.gca().scatter(data_norm['FirstObjectDistance_X'], data_norm['FirstObjectDistance_Y'], marker='.')

# %%
plt.gca().scatter(data_norm['Timestamp'], data_norm['VehicleSpeed'], marker='.')

# %%
plt.gca().scatter(data_norm['FirstObjectDistance_X'], data_norm['FirstObjectDistance_Y'], marker='.', c='Blue')
plt.gca().scatter(data_norm['SecondObjectDistance_X'], data_norm['SecondObjectDistance_Y'], marker='.')
plt.gca().scatter(data_norm['ThirdObjectDistance_X'], data_norm['ThirdObjectDistance_Y'], marker='.')
plt.gca().scatter(data_norm['FourthObjectDistance_X'], data_norm['FourthObjectDistance_Y'], marker='.')
# Out:
# <div id='b38dc56c-753b-4949-acd2-38920b348b71'></div>

# %%
for e in data_norm.values:
    plt.gca().scatter(e[0], e[1], marker='.')
    plt.gca().scatter(e[2], e[3], marker='.')
